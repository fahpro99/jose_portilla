# %% [markdown]
# ## testing

# %%
import streamlit as st
import pandas as pd
import folium
from streamlit_folium import folium_static

try:
    # Sample data (replace with your actual data loading code)
    df = pd.read_csv('output.csv')

    # Create a Streamlit map with attribution
    m = folium.Map(location=[23.6850, 90.3563], zoom_start=6, tiles='Mapbox Bright', attr='Mapbox attribution')

    # Choropleth layer
    choropleth = folium.Choropleth(
        geo_data='bd_jeoson.json',
        key_on='feature.properties.ADM2_EN',
        line_opacity=0.8,
        highlight=True,
    ).add_to(m)

    # Display the map in Streamlit
    folium_static(m)

except Exception as e:
    st.error(f"An error occurred: {e}")
# Out:
# 2023-12-11 11:15:25.819
# ...
#   command:
#
#     streamlit run C:\Users\fahim.anwar\AppData\Local\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
pip install streamlit
# Out:
# ...
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/d3/96/9251b421d0a1c7d625a82a04bea56b8a9830c785940ec16db454b85c6db7/streamlit-1.29.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/c5/e4/7fcceef127badbb0d644d730d992410e4f3799b295c9964a172f92a469c7/altair-5.2.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for blinker<2,>=1.0.0 from https://files.pythonhosted.org/packages/fa/2a/7f3714cbc6356a0efec525ce7a0613d581072ed6eb53eb7b9754f33db807/blinker-1.7.0-py3-none-any.whl.metadata
#   Using cached blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# ...
#   Obtaining dependency information for cachetools<6,>=4.0 from https://files.pythonhosted.org/packages/a2/91/2d843adb9fbd911e0da45fbf6f18ca89d07a087c3daa23e955584f90ebf4/cachetools-5.3.2-py3-none-any.whl.metadata
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# ...

# %%
pip install streamlit_folium
# Out:
# ...
#
#   Obtaining dependency information for streamlit_folium from https://files.pythonhosted.org/packages/22/1b/abb96f48921c52d4e6abb035f434fcb8044f18ebfc6a303017c7f9af233f/streamlit_folium-0.17.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for folium!=0.15.0,>=0.13 from https://files.pythonhosted.org/packages/18/09/8569904c8ce5679cc02826d98de633c07abcd2443a23181e5f71ff9dacbc/folium-0.15.1-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/325.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/325.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/325.3 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/325.3 kB 262.6 kB/s eta 0:00:02
#    -------- ------------------------------ 71.7/325.3 kB 393.8 kB/s eta 0:00:01
#    ------------- ------------------------ 112.6/325.3 kB 547.6 kB/s eta 0:00:01
#    ----------------------- -------------- 204.8/325.3 kB 778.2 kB/s eta 0:00:01
# ...
